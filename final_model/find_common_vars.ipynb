# %%
from pathlib import Path
import uproot

file = Path('/eos/user/a/anunezde/Z_OUTPUT_eos/Final_Model/0807_JetTop/results/ggHH_kl_0_kt_1_bbww_dl_2022.root')

with uproot.open(file) as upfile:
    tree_3j1b = upfile['SL_res_3j_1b']
    tree_3j2b = upfile['SL_res_3j_2b']
    tree_4j1b = upfile['SL_res_4j_1b']
    tree_4j2b = upfile['SL_res_4j_2b']
