# %%
from core import AnalysisConfig, Reference, ObsType
from core.observable import get_obs_info
from utils.analyzer import Analyzer
from utils.plot_config import PlotLimits
from utils.workdirectory import WorkDirectory
from pathlib import Path
PROJECTDIR = Path('/eos/user/a/anunezde/Z_OUTPUT_eos/Disc_Study_New/')
CONFIG = AnalysisConfig('bamboo_hh/config/disc_study_new.yml')
make_ref = lambda llr_name: Reference.from_parts(['SL_4j_resolved'], [llr_name])
# Out:
# Welcome to JupyROOT 6.30/02

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
subprojectdir = PROJECTDIR / 'crtd_final'
crtd_dirs = [d for d in subprojectdir.iterdir() if d.is_dir() and 'LLR_cmb' in d.name]
for i, d in enumerate(crtd_dirs): print(i, d.name)
# Out:
# 0 LLR_cmb10_b0
# 1 LLR_cmb10_b1
# 2 LLR_cmb10_b2
# 3 LLR_cmb11
# 4 LLR_cmb12to15
# 5 LLR_cmb2to3
# 6 LLR_cmb4
# 7 LLR_cmb5_b0
# 8 LLR_cmb5_b1
# 9 LLR_cmb5_b2
# 10 LLR_cmb6_b0
# 11 LLR_cmb6_b1
# 12 LLR_cmb6_b2
# 13 LLR_cmb6_b3
# 14 LLR_cmb7_b0
# 15 LLR_cmb7_b1
# 16 LLR_cmb7_b2
# 17 LLR_cmb7_b3
# 18 LLR_cmb7_b4
# 19 LLR_cmb8_b0
# 20 LLR_cmb8_b1
# 21 LLR_cmb8_b2
# 22 LLR_cmb8_b3
# 23 LLR_cmb8_b4
# 24 LLR_cmb9_b0
# 25 LLR_cmb9_b1
# 26 LLR_cmb9_b2
# 27 LLR_cmb9_b3

# %%
show_var_dim = lambda ref: print('vars: ', len(get_obs_info(ref).vars))

# %%
ref_2var = make_ref('jj_l_dR_x_bjets_pt_bb_llr')
ref_3var = make_ref('jj_l_dR_x_WW_mInv_x_bjets_pt_bb_llr')
ref_4var = make_ref('jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_WW_pt_llr')
ref_5var = make_ref('jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_WW_pt_x_bjets_dPhi_llr')
ref_6var = make_ref('jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_bjets_dR_x_WW_pt_x_bjets_dPhi_llr')
ref_7var = make_ref('jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_bjets_dR_x_blnu_bl_mInv_x_WW_pt_x_bjets_dPhi_llr')
ref_8var = make_ref('jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_bjets_dR_x_blnu_bl_mInv_x_WW_pt_x_bjets_mbb_x_bjets_dPhi_llr')

# %%
wd = WorkDirectory(crtd_dirs[5])
llr_analyzer = Analyzer(wd, CONFIG, outdir=Path('llr_study'))
show_var_dim(ref_2var)
llr_analyzer.plot_sig_bkg(ref_2var, PlotLimits(xmin=-4, xmax=6, ymax=0.06))
show_var_dim(ref_3var)
llr_analyzer.plot_sig_bkg(ref_3var, PlotLimits(xmin=-5, xmax=7, ymax=0.06))
# Out:
# vars:  2
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/anunezde/ipykernel_378575/781669935.py in <module>
#       2 llr_analyzer = Analyzer(wd, CONFIG, outdir=Path('llr_study'))
#       3 show_var_dim(ref_2var)
# ----> 4 llr_analyzer.plot_sig_bkg(ref_2var, PlotLimits(xmin=-4, xmax=6, ymax=0.06))
#       5 show_var_dim(ref_3var)
#       6 llr_analyzer.plot_sig_bkg(ref_3var, PlotLimits(xmin=-5, xmax=7, ymax=0.06))
#
# ~/bamboodev/hh/utils/analyzer.py in plot_sig_bkg(self, ref, limits, style, eras)
#      67     def plot_sig_bkg(self, ref, limits: PlotLimits = None, style: PlotStyle = PlotStyle(), eras=None):
#      68         signal_hist, background_hist = self.get_signal_background(ref, eras=eras)
# ---> 69         ax_limits, ax_labels = self._build_ax_labels_limits(ref, user_limits=limits)
#      70         save_path = self.outdir / f"{ref.name}.pdf"
#      71
#
# ~/bamboodev/hh/utils/analyzer.py in _build_ax_labels_limits(self, ref, user_limits)
#      29
#      30     def _build_ax_labels_limits(self, ref: Reference, user_limits = None) -> tuple[PlotLimits, tuple[str, ...]]:
# ---> 31         from bamboo_hh.variables import REG
#      32         info = get_obs_info(ref)
#      33         limits = user_limits or PlotLimits()
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105/x86_64-el9-gcc11-opt/lib/ROOT/_facade.py in _importhook(name, *args, **kwds)
#     152                 except Exception:
#     153                     pass
# --> 154             return _orig_ihook(name, *args, **kwds)
#     155         __builtin__.__import__ = _importhook
#     156
#
# ~/bamboodev/hh/bamboo_hh/variables/__init__.py in <module>
#       3 import os, yaml
#       4
# ----> 5 from .models import SuperVariable1D, Variable1D, VariableND
#       6 from .register import VariableRegister
#       7 from .definitions import REG  # 1D only; REG is augmented below
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105/x86_64-el9-gcc11-opt/lib/ROOT/_facade.py in _importhook(name, *args, **kwds)
#     152                 except Exception:
#     153                     pass
# --> 154             return _orig_ihook(name, *args, **kwds)
#     155         __builtin__.__import__ = _importhook
#     156
#
# ~/bamboodev/hh/bamboo_hh/variables/models.py in <module>
# ----> 1 from bamboo.plots import EquidistantBinning as EqBin
#       2 from bamboo.treeproxies import FloatProxy, IntProxy
#       3 from dataclasses import dataclass
#       4 from typing import Optional, Union
#       5 from core import Reference
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105/x86_64-el9-gcc11-opt/lib/ROOT/_facade.py in _importhook(name, *args, **kwds)
#     152                 except Exception:
#     153                     pass
# --> 154             return _orig_ihook(name, *args, **kwds)
#     155         __builtin__.__import__ = _importhook
#     156
#
# ~/.local/lib/python3.9/site-packages/bamboo/plots.py in <module>
#      13 from itertools import chain
#      14
# ---> 15 from . import treefunctions as op
#      16 from . import treeoperations as top
#      17 from .treeproxies import adaptArg
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_105/x86_64-el9-gcc11-opt/lib/ROOT/_facade.py in _importhook(name, *args, **kwds)
#     152                 except Exception:
#     153                     pass
# --> 154             return _orig_ihook(name, *args, **kwds)
#     155         __builtin__.__import__ = _importhook
#     156
#
# ~/.local/lib/python3.9/site-packages/bamboo/treefunctions.py in <module>
#       6 from .root import loadBambooExtensions
#       7
# ----> 8 loadBambooExtensions()
#       9
#      10 _logger = logging.getLogger(__name__)
#
# ~/.local/lib/python3.9/site-packages/bamboo/root.py in __call__(self, **kwargs)
#     102         if not self.has_run:
#     103             self.has_run = True
# --> 104             return self.fun(**kwargs)
#     105
#     106
#
# ~/.local/lib/python3.9/site-packages/bamboo/root.py in loadBambooExtensions()
#     126     # now load default headers and libraries
#     127     for lib in _defaultBambooLibs:
# --> 128         loadLibrary(f"lib{lib}")
#     129     for fname in _defaultHeaders:
#     130         loadHeader(fname)
#
# ~/.local/lib/python3.9/site-packages/bamboo/root.py in loadLibrary(libName)
#      39         raise RuntimeError(f"Library {libName} could not be found")
#      40     elif st == -2:
# ---> 41         raise RuntimeError(f"Version match for library {libName}")
#      42
#      43
#
# RuntimeError: Version match for library libBambooRandom
# Error in <TUnixSystem::Load>: version mismatch, /afs/cern.ch/user/a/anunezde/.local/lib/python3.9/site-packages/bamboo/lib/libBambooRandom.so = 62604, ROOT = 63002

# %%
wd = WorkDirectory(crtd_dirs[6])
llr_analyzer = Analyzer(wd, CONFIG, outdir=Path('llr_study'))
show_var_dim(ref_4var)
llr_analyzer.plot_sig_bkg(ref_4var, PlotLimits(xmin=-6, xmax=8, ymax=0.06))
# Out:
# vars:  4
# Figure saved to llr_study/SL_4j_resolved___jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_WW_pt_llr.pdf

# %%
wd = WorkDirectory(crtd_dirs[7])
refs = wd.get_references(channels=['SL_4j_resolved'])
llr_analyzer = Analyzer(wd, CONFIG, outdir=Path('llr_study'))
show_var_dim(ref_5var)
llr_analyzer.plot_sig_bkg(ref_5var, PlotLimits(xmin=-7, xmax=9, ymax=0.06))
# Out:
# vars:  5
# Figure saved to llr_study/SL_4j_resolved___jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_WW_pt_x_bjets_dPhi_llr.pdf

# %%
wd = WorkDirectory(crtd_dirs[10])   # 10 to 13
llr_analyzer = Analyzer(wd, CONFIG, outdir=Path('llr_study'))
show_var_dim(ref_6var)
llr_analyzer.plot_sig_bkg(ref_6var, PlotLimits(xmin=-8, xmax=11, ymax=0.06))
# Out:
# vars:  6
# Figure saved to llr_study/SL_4j_resolved___jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_bjets_dR_x_WW_pt_x_bjets_dPhi_llr.pdf

# %%
wd = WorkDirectory(crtd_dirs[15])   # 14 to 18
llr_analyzer = Analyzer(wd, CONFIG, outdir=Path('llr_study'))
show_var_dim(ref_7var)
llr_analyzer.plot_sig_bkg(ref_7var, PlotLimits(xmin=-9, xmax=12, ymax=0.06))
# Out:
# vars:  7
# Figure saved to llr_study/SL_4j_resolved___jj_l_dR_x_WW_mInv_x_bjets_pt_bb_x_bjets_dR_x_blnu_bl_mInv_x_WW_pt_x_bjets_dPhi_llr.pdf
