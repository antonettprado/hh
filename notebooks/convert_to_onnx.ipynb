# %%
import tf2onnx
from pathlib import Path
from neural_net.utils import log_msg
import tensorflow as tf
from neural_net.model_design import CustomStandardizer, ReplaceUndefinedValuesWithConstant

# %%
NN_roster_dir = Path('/eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster')

modeldirs = [dir for dir in  NN_roster_dir.iterdir() if dir.is_dir()]
print([m.name for m in modeldirs])
# Out:
# ['multi_HH_ttbar_WJets_3j', 'multi_HH_ttbar_WJets_4j', 'multi_HH_ttbar_tW_3j', 'multi_HH_ttbar_tW_4j', 'multi_HH_ttbar_tW_WJets_3j', 'multi_HH_ttbar_tW_WJets_4j']

# %%
def convert_model_to_onnx(saved_model: Path, outdir:Path, logger=None):    
    onnx_output = outdir / "dnn_model.onnx"
    try:
        if saved_model.exists():
            log_msg(f"Converting best checkpoint to ONNX: {onnx_output}")
            best_model = tf.keras.models.load_model(
                saved_model,
                custom_objects={
                    "CustomStandardizer": CustomStandardizer, 
                    "ReplaceUndefinedValuesWithConstant": ReplaceUndefinedValuesWithConstant}
            )
            tf2onnx.convert.from_keras(best_model, output_path=onnx_output)
    except Exception as e:
        log_msg(f"ONNX conversion failed: {e}", logger)

# %%
for modeldir in modeldirs:
    for passdir in modeldir.iterdir():
        if passdir.is_dir():
            onnx_path = passdir / "dnn_model.onnx"
            if onnx_path.exists():
                print(f"{onnx_path} already exists ... Skipping")
                continue
            model = passdir / 'best_checkpoint'
            if model.exists():
                convert_model_to_onnx(model, passdir)
                print(f"Converting {model} to ONNX...")
            else:
                print(f"No best_checkpoint found in {passdir}")
# Out:
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_3j/Pass0/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_3j/Pass1/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_3j/Pass2/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_3j/Pass3/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_3j/Pass4/dnn_model.onnx already exists ... Skipping
# Converting best checkpoint to ONNX: /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass0/dnn_model.onnx
# Could not search for non-variable resources. Concrete function internal representation may have changed.
# 2025-07-30 23:30:19.892897: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:19.893207: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2025-07-30 23:30:20.106989: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:20.107157: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# Converting /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass0/best_checkpoint to ONNX...
# Converting best checkpoint to ONNX: /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass1/dnn_model.onnx
# Could not search for non-variable resources. Concrete function internal representation may have changed.
# 2025-07-30 23:30:23.634755: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:23.635007: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2025-07-30 23:30:23.852254: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:23.852773: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# Converting /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass1/best_checkpoint to ONNX...
# Converting best checkpoint to ONNX: /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass2/dnn_model.onnx
# Could not search for non-variable resources. Concrete function internal representation may have changed.
# 2025-07-30 23:30:27.307005: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:27.307194: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2025-07-30 23:30:27.502356: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:27.502582: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# Converting /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass2/best_checkpoint to ONNX...
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass3/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_WJets_4j/Pass4/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_3j/Pass0/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_3j/Pass1/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_3j/Pass2/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_3j/Pass3/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_3j/Pass4/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_4j/Pass0/dnn_model.onnx already exists ... Skipping
# Converting best checkpoint to ONNX: /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_4j/Pass1/dnn_model.onnx
# Could not search for non-variable resources. Concrete function internal representation may have changed.
# 2025-07-30 23:30:31.030344: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:31.030482: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2025-07-30 23:30:31.230662: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:31.230844: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# Converting /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_4j/Pass1/best_checkpoint to ONNX...
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_4j/Pass2/dnn_model.onnx already exists ... Skipping
# Converting best checkpoint to ONNX: /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_4j/Pass3/dnn_model.onnx
# Could not search for non-variable resources. Concrete function internal representation may have changed.
# 2025-07-30 23:30:34.190947: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:34.191129: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2025-07-30 23:30:34.402526: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:34.402849: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# Converting /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_4j/Pass3/best_checkpoint to ONNX...
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_4j/Pass4/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_3j/Pass0/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_3j/Pass1/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_3j/Pass2/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_3j/Pass3/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_3j/Pass4/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_4j/Pass0/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_4j/Pass1/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_4j/Pass2/dnn_model.onnx already exists ... Skipping
# /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_4j/Pass3/dnn_model.onnx already exists ... Skipping
# Converting best checkpoint to ONNX: /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_4j/Pass4/dnn_model.onnx
# Could not search for non-variable resources. Concrete function internal representation may have changed.
# 2025-07-30 23:30:37.681901: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:37.682135: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2025-07-30 23:30:37.878067: I tensorflow/core/grappler/devices.cc:75] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2025-07-30 23:30:37.878242: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# Converting /eos/user/a/anunezde/Z_OUTPUT_eos/Run3_0626/Vars_AllEvs/NN_roster/multi_HH_ttbar_tW_WJets_4j/Pass4/best_checkpoint to ONNX...
