# %%
from bamboo_hh_new.definitions.variables import REG
# Out:
# Welcome to JupyROOT 6.30/02

# %%
REG.get_var1D_names()
# Out:
# ['bjets_mbb',
#  'bjets_dPhi',
#  'bjets_dEta',
#  'bjets_dR',
#  'bjets_pt_bb',
#  'bjet0_pt',
#  'bjet1_pt',
#  'bjets_mean_pt',
#  'bfatjet_mass',
#  'bfatjet_msoftdrop',
#  'trijet_mInv',
#  'trijet_pt',
#  'trijet_pt_rat',
#  'trijet_bijet_dR',
#  'trijet_bijet_dPhi',
#  'trijet_bijet_dEta',
#  'bjet_bijet_dR',
#  'bjet_bijet_dPhi',
#  'bjet_bijet_dEta',
#  'blnu_mT',
#  'blnu_pt',
#  'blnu_bl_mInv',
#  'blnu_lnu_mT',
#  'all_sT',
#  'all_mInv',
#  'all_mT',
#  'all_jets_HT',
#  'all_pt',
#  'mjj',
#  'WW_mInv',
#  'WW_mT',
#  'WW_pt',
#  'jj_l_dEta',
#  'jj_l_dPhi',
#  'jj_l_dR',
#  'jj_lnu_dEta',
#  'jj_lnu_dPhi',
#  'jj_lnu_dR',
#  'bb_lnu_dEta',
#  'bb_lnu_dPhi',
#  'bb_lnu_dR',
#  'min_b_l_dPhi',
#  'min_b_l_dR',
#  'min_b_lnu_dPhi',
#  'lep0_pt',
#  'lep0_eta',
#  'lep0_phi',
#  'lep0_iso',
#  'lep1_pt',
#  'lep1_eta',
#  'lep1_phi',
#  'lep1_iso',
#  'ak4_jet0_pt',
#  'ak4_jet0_eta',
#  'ak4_jet0_phi',
#  'ak4_jet0_bscore',
#  'ak4_jet1_pt',
#  'ak4_jet1_eta',
# ...

# %%
print("1D variables:", REG.get_var1D_names())
print("ND variables:", REG.get_varND_names())
print("Binning for 'bjets_mbb':", REG.get_var1D_binning("bjets_mbb"))
# Out:
# 1D variables: ['bjets_mbb', 'bjets_dPhi', 'bjets_dEta', 'bjets_dR', 'bjets_pt_bb', 'bjet0_pt', 'bjet1_pt', 'bjets_mean_pt', 'bfatjet_mass', 'bfatjet_msoftdrop', 'trijet_mInv', 'trijet_pt', 'trijet_pt_rat', 'trijet_bijet_dR', 'trijet_bijet_dPhi', 'trijet_bijet_dEta', 'bjet_bijet_dR', 'bjet_bijet_dPhi', 'bjet_bijet_dEta', 'blnu_mT', 'blnu_pt', 'blnu_bl_mInv', 'blnu_lnu_mT', 'all_sT', 'all_mInv', 'all_mT', 'all_jets_HT', 'all_pt', 'mjj', 'WW_mInv', 'WW_mT', 'WW_pt', 'jj_l_dEta', 'jj_l_dPhi', 'jj_l_dR', 'jj_lnu_dEta', 'jj_lnu_dPhi', 'jj_lnu_dR', 'bb_lnu_dEta', 'bb_lnu_dPhi', 'bb_lnu_dR', 'min_b_l_dPhi', 'min_b_l_dR', 'min_b_lnu_dPhi', 'lep0_pt', 'lep0_eta', 'lep0_phi', 'lep0_iso', 'lep1_pt', 'lep1_eta', 'lep1_phi', 'lep1_iso', 'ak4_jet0_pt', 'ak4_jet0_eta', 'ak4_jet0_phi', 'ak4_jet0_bscore', 'ak4_jet1_pt', 'ak4_jet1_eta', 'ak4_jet1_phi', 'ak4_jet1_bscore', 'ak4_jet2_pt', 'ak4_jet2_eta', 'ak4_jet2_phi', 'ak4_jet2_bscore', 'ak4_jet3_pt', 'ak4_jet3_eta', 'ak4_jet3_phi', 'ak4_jet3_bscore', '
# ...

# %%
leaf_names=['index', 'event', 'genWeight', 'bjets_mbb', 'bjets_dPhi', 'bjets_dEta', 'bjets_dR', 'bjets_pt_bb', 'bjet0_pt', 'bjet1_pt', 'bjets_mean_pt', 'trijet_mInv', 'trijet_pt', 'trijet_pt_rat', 'trijet_bijet_dR', 'trijet_bijet_dPhi', 'trijet_bijet_dEta', 'bjet_bijet_dR', 'bjet_bijet_dPhi', 'bjet_bijet_dEta', 'blnu_mT', 'blnu_pt', 'blnu_bl_mInv', 'blnu_lnu_mT', 'all_sT', 'all_mInv', 'all_mT', 'all_jets_HT', 'all_pt', 'mjj', 'WW_mInv', 'WW_mT', 'WW_pt', 'jj_l_dEta', 'jj_l_dPhi', 'jj_l_dR', 'jj_lnu_dEta', 'jj_lnu_dPhi', 'jj_lnu_dR', 'bb_lnu_dEta', 'bb_lnu_dPhi', 'bb_lnu_dR', 'min_b_l_dPhi', 'min_b_l_dR', 'min_b_lnu_dPhi', 'lep0_pt', 'lep0_eta', 'lep0_phi', 'lep0_iso', 'ak4_jet0_pt', 'ak4_jet0_eta', 'ak4_jet0_phi', 'ak4_jet0_bscore', 'ak4_jet1_pt', 'ak4_jet1_eta', 'ak4_jet1_phi', 'ak4_jet1_bscore', 'ak4_jet2_pt', 'ak4_jet2_eta', 'ak4_jet2_phi', 'ak4_jet2_bscore', 'ak4_jet3_pt', 'ak4_jet3_eta', 'ak4_jet3_phi', 'ak4_jet3_bscore', 'met_pt', 'met_phi', 'nAK4', 'nAK4_btag', 'nAK4_nonbtag', 'nAK8_btag', 'era']
valid_vars=['bjets_mbb', 'bjets_dPhi', 'bjets_dEta', 'bjets_dR', 'bjets_pt_bb', 'bjet0_pt', 'bjet1_pt', 'bjets_mean_pt', 'trijet_mInv', 'trijet_pt', 'trijet_pt_rat', 'trijet_bijet_dR', 'trijet_bijet_dPhi', 'trijet_bijet_dEta', 'bjet_bijet_dR', 'bjet_bijet_dPhi', 'bjet_bijet_dEta', 'blnu_mT', 'blnu_pt', 'blnu_bl_mInv', 'blnu_lnu_mT', 'all_sT', 'all_mInv', 'all_mT', 'all_jets_HT', 'all_pt', 'mjj', 'WW_mInv', 'WW_mT', 'WW_pt', 'jj_l_dEta', 'jj_l_dPhi', 'jj_l_dR', 'jj_lnu_dEta', 'jj_lnu_dPhi', 'jj_lnu_dR', 'bb_lnu_dEta', 'bb_lnu_dPhi', 'bb_lnu_dR', 'min_b_l_dPhi', 'min_b_l_dR', 'min_b_lnu_dPhi', 'lep0_pt', 'lep0_eta', 'lep0_phi', 'lep0_iso', 'ak4_jet0_pt', 'ak4_jet0_eta', 'ak4_jet0_phi', 'ak4_jet0_bscore', 'ak4_jet1_pt', 'ak4_jet1_eta', 'ak4_jet1_phi', 'ak4_jet1_bscore', 'ak4_jet2_pt', 'ak4_jet2_eta', 'ak4_jet2_phi', 'ak4_jet2_bscore', 'ak4_jet3_pt', 'ak4_jet3_eta', 'ak4_jet3_phi', 'ak4_jet3_bscore', 'met_pt', 'met_phi', 'nAK4', 'nAK4_btag', 'nAK4_nonbtag', 'nAK8_btag', 'era']
branches = ['bjets_mbb', 'bjets_dPhi', 'bjets_dEta', 'bjets_dR', 'bjets_pt_bb', 'bjet0_pt', 'bjet1_pt', 'bjets_mean_pt', 'trijet_mInv', 'trijet_pt', 'trijet_pt_rat', 'trijet_bijet_dR', 'trijet_bijet_dPhi', 'trijet_bijet_dEta', 'bjet_bijet_dR', 'bjet_bijet_dPhi', 'bjet_bijet_dEta', 'blnu_mT', 'blnu_pt', 'blnu_bl_mInv', 'blnu_lnu_mT', 'all_sT', 'all_mInv', 'all_mT', 'all_jets_HT', 'all_pt', 'mjj', 'WW_mInv', 'WW_mT', 'WW_pt', 'jj_l_dEta', 'jj_l_dPhi', 'jj_l_dR', 'jj_lnu_dEta', 'jj_lnu_dPhi', 'jj_lnu_dR', 'bb_lnu_dEta', 'bb_lnu_dPhi', 'bb_lnu_dR', 'min_b_l_dPhi', 'min_b_l_dR', 'min_b_lnu_dPhi', 'lep0_pt', 'lep0_eta', 'lep0_phi', 'lep0_iso', 'ak4_jet0_pt', 'ak4_jet0_eta', 'ak4_jet0_phi', 'ak4_jet0_bscore', 'ak4_jet1_pt', 'ak4_jet1_eta', 'ak4_jet1_phi', 'ak4_jet1_bscore', 'ak4_jet2_pt', 'ak4_jet2_eta', 'ak4_jet2_phi', 'ak4_jet2_bscore', 'ak4_jet3_pt', 'ak4_jet3_eta', 'ak4_jet3_phi', 'ak4_jet3_bscore', 'met_pt', 'met_phi', 'nAK4', 'nAK4_btag', 'nAK4_nonbtag', 'nAK8_btag', 'era', 'event']
